# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/SM(Haithaikheda)2018-2022 .csv',parse_dates=True)
df["date"] = pd.to_datetime(df["date"], errors='coerce')
df['Year'] = pd.to_datetime(df['date']).dt.strftime('%Y')
df['Month'] = pd.to_datetime(df['date']).dt.strftime('%m')
df['Day'] = pd.to_datetime(df['date']).dt.strftime('%d')
df=df.set_index("date")
df
# Out:
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# ...
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '26-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '31-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '19-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '23-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '13-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '14-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '15-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '16-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '17-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '18-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '20-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '21-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '22-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '24-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '25-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '27-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '28-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '29-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
# <ipython-input-75-6ce8d3ae4577>:2: UserWarning: Parsing '30-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"], errors='coerce')
#             Suspended Matter  Year Month Day
# date
# 2018-02-01          0.423854  2018    02  01
# 2018-03-01          0.472505  2018    03  01
# 2018-06-01          0.550982  2018    06  01
# 2018-07-01          0.444331  2018    07  01
# 2018-10-01          0.442788  2018    10  01
# ...                      ...   ...   ...  ..
# 2022-12-25          0.441013  2022    12  25
# 2022-12-27          0.508801  2022    12  27
# 2022-12-28          0.424783  2022    12  28
# 2022-12-29          0.413495  2022    12  29
# 2022-12-30          0.476573  2022    12  30
#
# [1490 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Suspended Matter', 'Year', 'Month', 'Day'], dtype='object')

# %%
df1=df.filter(['Suspended Matter'])

# %%
df1=df.filter(['Suspended Matter'])
df1
# Out:
#             Suspended Matter
# date
# 2018-02-01          0.423854
# 2018-03-01          0.472505
# 2018-06-01          0.550982
# 2018-07-01          0.444331
# 2018-10-01          0.442788
# ...                      ...
# 2022-12-25          0.441013
# 2022-12-27          0.508801
# 2022-12-28          0.424783
# 2022-12-29          0.413495
# 2022-12-30          0.476573
#
# [1490 rows x 1 columns]

# %%
df1.describe()
# Out:
#        Suspended Matter
# count       1485.000000
# mean           0.520904
# std            0.072725
# min            0.362842
# 25%            0.455417
# 50%            0.520607
# 75%            0.584819
# max            0.719999

# %%
df = df[~df.index.duplicated()]

# %%
limit = 0.500
fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(x='Suspended Matter', data=df[df['Suspended Matter'] <= limit], color='green', label=f'Suspended Matter <= {limit}')
sns.histplot(x='Suspended Matter', data=df[df['Suspended Matter'] > limit], color='yellow', label=f'Suspended Matter > {limit}', ax=ax)
ax.set_xlabel('Suspended Matter')
ax.set_ylabel('Count')
ax.legend()
plt.show()

# %% [markdown]
# 60% of the suspended matter is fine remaining other 40% of it requires treatment

# %%
df = pd.read_csv('/content/DOM(Final) .csv',parse_dates=True)
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
df['Year'] = pd.to_datetime(df['Date']).dt.strftime('%Y')
df['Month'] = pd.to_datetime(df['Date']).dt.strftime('%m')
df['Day'] = pd.to_datetime(df['Date']).dt.strftime('%d')
df=df.set_index("Date")
df
# Out:
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# ...
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '17-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '20-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '30-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '31-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '14-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '15-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '16-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '18-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '19-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '21-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '22-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '23-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '24-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '25-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '26-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '27-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '28-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
# <ipython-input-101-f43bd0dc1bb4>:2: UserWarning: Parsing '29-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
#             Unnamed: 0 Dissolved Organic Matter  Year Month  Day
# Date
# 2018-02-01         0.0              0.520072019  2018    02   01
# 2018-03-01         1.0              0.425592746  2018    03   01
# 2018-06-01         2.0              0.479395316  2018    06   01
# 2018-07-01         3.0              0.418288863  2018    07   01
# 2018-10-01         4.0              0.384030788  2018    10   01
# ...                ...                      ...   ...   ...  ...
# NaT                NaN                      NaN   NaN   NaN  NaN
# NaT                NaN                      NaN   NaN   NaN  NaN
# NaT                NaN                      NaN   NaN   NaN  NaN
# NaT                NaN                      NaN   NaN   NaN  NaN
# NaT                NaN                        s   NaN   NaN  NaN
#
# [1556 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Dissolved Organic Matter', 'Year', 'Month', 'Day'], dtype='object')

# %%
df2=df.filter(['Dissolved Organic Matter'])
df2
# Out:
#            Dissolved Organic Matter
# Date
# 2018-02-01              0.520072019
# 2018-03-01              0.425592746
# 2018-06-01              0.479395316
# 2018-07-01              0.418288863
# 2018-10-01              0.384030788
# ...                             ...
# NaT                             NaN
# NaT                             NaN
# NaT                             NaN
# NaT                             NaN
# NaT                               s
#
# [1556 rows x 1 columns]

# %%
df2.describe()
# Out:
#        Dissolved Organic Matter
# count                      1378
# unique                     1378
# top                 0.520072019
# freq                          1

# %%
df = df[~df.index.duplicated()]

# %% [markdown]
# The column  Dissolved Organic Matter has different types of attributes to avoid error we'll be first changing all of them to float data type and then proceed.

# %%
df['Dissolved Organic Matter'] = df['Dissolved Organic Matter'].astype(float)
# Out:
# <ipython-input-108-f0909384a5a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dissolved Organic Matter'] = df['Dissolved Organic Matter'].astype(float)

# %%
fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(x='Dissolved Organic Matter', data=df[(df['Dissolved Organic Matter'] <0.5 )], color='green', label='Dissolved Organic Matter < 0.5')
sns.histplot(x='Dissolved Organic Matter', data=df[(df['Dissolved Organic Matter'] >= 0.5) & (df['Dissolved Organic Matter'] <=2)], color='yellow', label='0.5 < Dissolved Organic Matter < 2')
sns.histplot(x='Dissolved Organic Matter', data=df[(df['Dissolved Organic Matter'] > 2 )], color='red', label='Dissolved Organic Matter >= 2')
ax.set_xlabel('Dissolved Organic Matter')
ax.set_ylabel('Count')
ax.legend()
plt.show()

# %% [markdown]
# 50% of the Dissolved Organic matter is fine remaining 50% of it requires treatment.
