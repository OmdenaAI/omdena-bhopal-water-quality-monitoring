# %%
import pandas as pd

# %%
df = pd.read_csv("manit_lake_data.csv")

# %%
df
# Out:
#           ndwi   mndwi      ndci      ndti        do      ndsi        ph  \
# 0          NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 3          NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 4          NaN     NaN       NaN       NaN       NaN       NaN       NaN
# ...        ...     ...       ...       ...       ...       ...       ...
# 1821 -0.181104 -0.0909  0.010244 -0.109956  0.010498 -0.198462  7.872754
# 1822       NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 1823       NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 1824       NaN     NaN       NaN       NaN       NaN       NaN       NaN
# 1825       NaN     NaN       NaN       NaN       NaN       NaN       NaN
#
#          chl_a      ssc         wst        date
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#           ndwi     mndwi      ndci      ndti        do      ndsi        ph  \
# 351  -0.171468 -0.086772 -0.047175 -0.063077  0.051968 -0.146016  7.875224
# 356  -0.200477 -0.113391 -0.053013 -0.140656 -0.001589 -0.243110  7.996926
# 361  -0.200412 -0.120371 -0.050189 -0.157018 -0.017669 -0.267052  7.977569
# 366  -0.200677 -0.125254 -0.043067 -0.122370  0.000287 -0.237849  8.021176
# 371  -0.116030 -0.050132 -0.030745  0.053427  0.151590  0.003790  7.747242
# ...        ...       ...       ...       ...       ...       ...       ...
# 1796 -0.206198 -0.093135  0.009773 -0.144107  0.026511 -0.233576  7.938699
# 1801 -0.211172 -0.107049  0.020190 -0.149840  0.007363 -0.252360  7.939485
# 1811 -0.178464 -0.080391  0.008990 -0.146839  0.000342 -0.224186  7.860374
# 1816 -0.175838 -0.080282  0.005703 -0.148272 -0.003362 -0.225376  7.874172
# 1821 -0.181104 -0.090900  0.010244 -0.109956  0.010498 -0.198462  7.872754
#
#           chl_a       ssc         wst        date
# ...

# %%
df = df.drop(columns=['ndwi','mndwi','ndci',])

# %%
df
# Out:
#           ndti        do      ndsi        ph      chl_a       ssc         wst  \
# 351  -0.063077  0.051968 -0.146016  7.875224  21.851049  2.581423 -250.414319
# 356  -0.140656 -0.001589 -0.243110  7.996926  22.850279  2.580932 -251.045688
# 361  -0.157018 -0.017669 -0.267052  7.977569  35.405450  2.580890 -251.577653
# 366  -0.122370  0.000287 -0.237849  8.021176  24.240241  2.580842 -250.087783
# 371   0.053427  0.151590  0.003790  7.747242  13.554217  2.581869 -244.343724
# ...        ...       ...       ...       ...        ...       ...         ...
# 1796 -0.144107  0.026511 -0.233576  7.938699  13.687200  2.581460 -200.274633
# 1801 -0.149840  0.007363 -0.252360  7.939485  16.287783  2.581313 -200.447588
# 1811 -0.146839  0.000342 -0.224186  7.860374  13.720117  2.581592 -201.523999
# 1816 -0.148272 -0.003362 -0.225376  7.874172  12.673392  2.581591 -200.040786
# 1821 -0.109956  0.010498 -0.198462  7.872754  14.928730  2.581490 -194.105437
#
#             date
# ...

# %%
import plotly.express as px
import plotly.graph_objs as go

# %%
fig = px.line(df, x='date', y='ndti')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='date', y='do')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='date', y='ph')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df,x='date',y='chl_a')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x='date', y='ssc')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.line(df,x='date',y='wst')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
